# %% [markdown]
# <a href="https://colab.research.google.com/github/himanshuc2406/Capstone-Project-Exploratory-Data-Analysis/blob/main/Capstone_Project_Exploratory_Data_Analysis_Paisabazaar_Banking_Fraud_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Exploratory Data Analysis-Paisabazaar Banking Fraud Analysis

# %% [markdown]
# ##### **Project Type**    - Exploratory Data Analysis (EDA) Project
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** -  Himanshu Chauhan

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project focuses on performing Exploratory Data Analysis (EDA) on the Paisabazaar Banking dataset to understand customer credit behavior and identify patterns affecting creditworthiness and potential fraud.
#
# The dataset consists of customer-level information such as demographic details, financial attributes, and credit performance metrics.
# It includes the following key columns:
#
# Identification Details: ID, Customer_ID, Name, SSN, Month
#
# Demographics: Age, Occupation
#
# Income & Salary: Annual_Income, Monthly_Inhand_Salary
#
# Banking and Credit Information: Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan
#
# Payment and Loan Behavior: Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Payment_Behaviour, Monthly_Balance
#
# Investment and Score: Amount_invested_monthly, Credit_Score
#
# The objective of this project is to explore and analyze these variables to gain insights into customer credit patterns, detect anomalies, and identify key indicators that impact credit score and financial risk.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Banks and financial institutions like Paisabazaar handle large volumes of customer credit and loan data every day.
# Understanding a customer’s financial behavior is essential to assess their creditworthiness, detect potential fraud, and minimize financial risk.
#
# The problem addressed in this project is to analyze customer-level financial data — including income, credit cards, loans, payment delays, and utilization ratios — to identify patterns that influence the Credit Score.
#
# By performing Exploratory Data Analysis (EDA), the goal is to:
#
# * Detect anomalies and irregular payment behaviors.
#
# * Identify relationships between key features such as income, loan count,   credit inquiries, and credit score.
#
# * Gain insights that can support credit risk assessment and fraud detection models in future stages.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The primary business objective of this project is to help Paisabazaar and similar financial institutions gain a deeper understanding of their customers’ credit behavior and financial reliability.
# By analyzing key attributes such as income, loan patterns, delayed payments, and credit utilization, the organization can:
#
# * Assess creditworthiness more accurately and reduce the risk of loan defaults.
#
# * Identify early signs of fraudulent or risky behavior through data-driven insights.
#
# * Improve decision-making in credit approvals, limit changes, and loan offerings.
#
# * Enhance customer segmentation by understanding financial habits and repayment behaviors.
#
# This Exploratory Data Analysis (EDA) lays the foundation for developing robust credit scoring models and fraud detection systems, ultimately helping Paisabazaar minimize financial risk and improve operational efficiency.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
#Basic Handlings
import numpy as np               # For numerical operation
import pandas as pd              # For data manipulation and analysis

#Visualization
import matplotlib.pyplot as plt  #For creating basic plots
import seaborn as sns            #For advance visualizations

#System & Utility modules
import warnings                  #To suppress unnecessary warnings
warnings.filterwarnings('ignore')
print('Libraries imported successfully')
# Out:
# Libraries imported successfully

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
data = pd.read_csv('/content/dataset_Paisa_bazar.csv', on_bad_lines='skip')

# %%
#Making a copy of main data
df = data.copy() #Working dataset

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#      ID  Customer_ID  Month           Name  Age        SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh   23  821000265  Scientist
# 1  5635         3392      2  Aaron Maashoh   23  821000265  Scientist
# 2  5636         3392      3  Aaron Maashoh   23  821000265  Scientist
# 3  5637         3392      4  Aaron Maashoh   23  821000265  Scientist
# 4  5638         3392      5  Aaron Maashoh   23  821000265  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                  3  ...        Good
# 1       19114.12            1824.843333                  3  ...        Good
# 2       19114.12            1824.843333                  3  ...        Good
# 3       19114.12            1824.843333                  3  ...        Good
# 4       19114.12            1824.843333                  3  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (100000, 28)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  int64
#  5   SSN                       100000 non-null  int64
#  6   Occupation                99995 non-null   object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  int64
#  10  Num_Credit_Card           100000 non-null  int64
#  11  Interest_Rate             100000 non-null  int64
#  12  Num_of_Loan               100000 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum().sort_values(ascending=False)
# Out:
# Credit_Score                7
# Occupation                  5
# Type_of_Loan                5
# Payment_of_Min_Amount       3
# Credit_Mix                  3
# Payment_Behaviour           2
# SSN                         0
# Age                         0
# Name                        0
# ID                          0
# Month                       0
# Customer_ID                 0
# Interest_Rate               0
# Num_Credit_Card             0
# Num_Bank_Accounts           0
# Monthly_Inhand_Salary       0
# Annual_Income               0
# Num_of_Delayed_Payment      0
# Delay_from_due_date         0
# Num_of_Loan                 0
# Outstanding_Debt            0
# Num_Credit_Inquiries        0
# Changed_Credit_Limit        0
# Credit_Utilization_Ratio    0
# Total_EMI_per_month         0
# Credit_History_Age          0
# Amount_invested_monthly     0
# Monthly_Balance             0
# dtype: int64

# %%
# Visualizing the missing values
#counting the missing values
missing = df.isnull().sum()
#keeping only those columns that has missing vlaues.
missing = missing[missing>0]

# Check if there are any missing values to plot
if not missing.empty:
    plt.figure(figsize=(10,6))
    missing.plot(kind= 'bar')
    plt.title('Missing Values per Column')
    plt.xlabel('\nColumns')
    plt.ylabel('Number of Missing Values')
    plt.xticks(rotation = 45)
    plt.show()
else:
    print("No missing values to visualize.")

# %% [markdown]
# #Why using Bar Graph for Missing values?
# * Q : Why did I use this chart?
# * Ans: A bar chart is simple and effective for comparing missing values across multiple columns.
# * Q : What did I find?
# * Ans:Nine columns have one missing value each, while others are complete
#
# * Business impact:
# * The dataset is clean, requiring minimal preprocessing — ensuring accuracy and time efficiency in downstream credit analysis.

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset consists of 100,000 records and 28 columns, containing detailed customer information related to their banking and credit activities from Paisabazaar.
#
# It includes both numerical and categorical data types:
#
# * Numerical Columns (21): Attributes such as Age, Annual_Income, Monthly_Inhand_Salary, Outstanding_Debt, Num_of_Loan, Credit_Utilization_Ratio, and Monthly_Balance capture quantitative financial metrics.
#
# * Categorical Columns (7): Features such as Occupation, Type_of_Loan, Credit_Mix, Payment_Behaviour, and Credit_Score describe qualitative aspects of customer credit and repayment patterns.
#
# The dataset is well-structured and clean, with:
#
# * Only 25 missing values (With 7 in Credit_Score, 5 in Occupation, 5 in Types_of_loan, 3 in Payment_of_Min_Amount, 3 on Credit,Mix, 2 in Payment_Behaviour).
#
# * No duplicate records present.
#
# Consistent data types (numeric fields stored as int or float, categorical fields as object).
#
# Overall, the dataset provides a comprehensive view of customer demographics, income levels, loan behavior, and credit history, making it ideal for performing Exploratory Data Analysis (EDA) to understand credit risk patterns and financial behavior trends.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#                   ID    Customer_ID          Month            Age  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean    80631.500000   25982.666640       4.500000      33.316340
# std     43301.486619   14340.543051       2.291299      10.764812
# min      5634.000000    1006.000000       1.000000      14.000000
# 25%     43132.750000   13664.500000       2.750000      24.000000
# 50%     80631.500000   25777.000000       4.500000      33.000000
# 75%    118130.250000   38385.000000       6.250000      42.000000
# max    155629.000000   50999.000000       8.000000      56.000000
#
#                 SSN  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  1.000000e+05  100000.000000          100000.000000      100000.000000
# mean   5.004617e+08   50505.123449            4197.270835           5.368820
# std    2.908267e+08   38299.422093            3186.432497           2.593314
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The dataset consists of 28 variables that describe customers’ demographic details, income, financial behavior, and credit performance.
# Each variable represents an important aspect of a customer’s financial profile that can influence their credit score and loan eligibility.
#
# * Demographic Variables:
# Customer_ID, Name, Age, Occupation, SSN — provide personal and identity details.
#
# * Income & Salary Variables:
# Annual_Income, Monthly_Inhand_Salary — show the customer’s earning capacity.
#
# * Banking & Credit Variables:
# Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan — describe credit exposure and banking relationships.
#
# * Payment Behavior Variables:
# Delay_from_due_date, Num_of_Delayed_Payment, Payment_Behaviour, Payment_of_Min_Amount — show how regularly customers make payments.
#
# * Debt & Credit Variables:
# Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Changed_Credit_Limit, Num_Credit_Inquiries — describe credit usage and repayment patterns.
#
# * Investment & Balance Variables:
# Amount_invested_monthly, Monthly_Balance, Total_EMI_per_month — indicate financial discipline and savings.
#
# * Target Variable:
# Credit_Score — classifies each customer’s credit rating as Good, Standard, or Poor.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique().sort_values(ascending=False)
# Out:
# ID                          100000
# Credit_Utilization_Ratio     99998
# Monthly_Balance              98492
# Monthly_Inhand_Salary        13241
# SSN                          12500
# Customer_ID                  12500
# Annual_Income                12488
# Amount_invested_monthly      12261
# Outstanding_Debt             12203
# Total_EMI_per_month          11890
# Name                         10128
# Type_of_Loan                  6261
# Changed_Credit_Limit          2860
# Credit_History_Age             404
# Delay_from_due_date             63
# Age                             43
# Interest_Rate                   34
# Num_of_Delayed_Payment          26
# Num_Credit_Inquiries            18
# Occupation                      15
# Num_Bank_Accounts               12
# Num_Credit_Card                 12
# Num_of_Loan                     10
# Month                            8
# Payment_Behaviour                6
# Credit_Mix                       3
# Payment_of_Min_Amount            3
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
#Droping Unnecessary columns
#Droping Columns like 'ID', 'Name', and 'SSN' as they are unique for each record but do not provide any meaningful insights or pattern for analyis, Hence, we removed it.
df.drop(['ID', 'Name','SSN'], axis = 1, inplace = True)


#Check for duplicate rows
#Duplicate rows can lead to biased analysis and incorrct insights, We check for dupicate value if any we found, we remove them.
print('Number of duplicate rows:', df.duplicated().sum)
df.drop_duplicates(inplace = True)

#Checking for missing values
#Even though the dateset looked clean earlier, it is always good practice to recheck as missing value can cause erros in visualization.
print('Total missing values:', df.isnull().sum().sum())
# Out:
# Number of duplicate rows: <bound method Series.sum of 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99995    False
# 99996    False
# 99997    False
# 99998    False
# 99999    False
# Length: 100000, dtype: bool>
# Total missing values: 25

# %%
#handling missing value using user defined function and replacing it with the median.
#It will give those columns which has numerical values.
num_cols = df.select_dtypes(include = ['float64', 'int64']).columns
#using for loops
for col in num_cols:
  if df[col].isnull().sum()>0:   #using condition if column have missing value and it is greater then 0
    df[col].fillna(df[col].median(), inplace = True)  #using fillna function to fill the missing values with median of that column
    print(f'Filled missing values in{col} with median.') #printing that missing values are sucessfully filled



#It will give those columns which has categorical columns
cat_cols = df.select_dtypes(['object']).columns

for col in cat_cols:     #using condition if column have missing value and it is greater then 0
  if df[col].isnull().sum()>0:#using condition if column have missing value and it is greater then 0
    df[col].fillna(df[col].mode()[0], inplace = True)#using fillna function to fill the missing values with mode of that column

  print(f'Filled missing values in {col} with mode') #printing that missing values are sucessfully filled

#Rechecking to confim no missing values remian
print('Missing value after cleaning', df.isnull().sum().sum())
# Out:
# Filled missing values in Occupation with mode
# Filled missing values in Type_of_Loan with mode
# Filled missing values in Credit_Mix with mode
# Filled missing values in Payment_of_Min_Amount with mode
# Filled missing values in Payment_Behaviour with mode
# Filled missing values in Credit_Score with mode
# Missing value after cleaning 0

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# During the data cleaning process, the following manipulations were performed to make the dataset analysis-ready:
#
# * Filled missing values in Occupation using the most frequent value (mode).
#
# * Filled missing values in Type_of_Loan using the most frequent value (mode).
#
# * Filled missing values in Credit_Mix using the most frequent value (mode).
#
# * Filled missing values in Payment_of_Min_Amount using the most frequent value (mode).
#
# * Filled missing values in Payment_Behaviour using the most frequent value (mode).
#
# * Filled missing values in Credit_Score using the most frequent value (mode).
#
# After performing these operations:
#
# * All missing values were successfully handled.
#
# * No null or missing entries remain in the dataset (Total missing values = 0).
#
# Insights from this step:
#
# * Most missing values occurred in categorical columns, not numerical ones — showing that the dataset mainly lacked descriptive information, not financial data.
#
# * Since we used the mode, the filled values maintain the original data distribution without introducing outliers.
#
# * The dataset is now completely clean and consistent, ready for Exploratory Data Analysis (EDA).

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 : Distribution of Annual Income

# %%
# Chart - 1 visualization code
plt.figure(figsize=(8,5))
plt.hist(df['Annual_Income'], bins=20, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Distribution of Annual Income')
plt.xlabel('Annual_Income')
plt.ylabel('Number of Customers')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is used to understand the distribution of a continuous numerical variable.
# Here, it helps visualize how customer incomes are spread across different ranges.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The distribution is right-skewed, meaning most customers have lower annual incomes.
#
# * A large number of customers earn between ₹10,000 and ₹40,000, while only a few have income above ₹1,00,000.
#
# * This suggests that the majority of Paisabazaar’s customers belong to the middle-income group.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive**
#
# This insight helps Paisabazaar target middle-income customers with suitable financial products such as personal loans, credit cards, or EMI-based services.
# The company can also design premium financial products for the smaller, high-income segment.
#
# **Negative**
#
# Over-reliance on middle-income customers could mean limited high-value transactions.
# The company should work to expand its reach to higher income segments to diversify business risk.

# %% [markdown]
# #### Chart - 2: Number of Customers by Occupation

# %%
# Chart - 2 visualization code
plt.figure(figsize=(10,6))
df['Occupation'].value_counts().plot(kind='bar')
plt.title('Number of Customers by Occupation')
plt.xlabel('Occupation')
plt.ylabel('Number of Customers')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is ideal for comparing the number of customers across different categorical groups, such as occupations.
# It helps visualize which professions contribute the most customers to Paisabazaar’s database.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The number of customers is fairly evenly distributed across occupations, with slightly higher counts for Architects, Lawyers, and Mechanics.
#
# * This suggests that Paisabazaar has a diverse customer base spread across multiple professional backgrounds.
#
# * The least represented occupations, such as Accountants and Managers, may offer opportunities for customer acquisition.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive**
#
# These insights indicate that Paisabazaar serves a wide range of working professionals, showing strong brand penetration across occupational categories.
# This allows the company to customize financial products (e.g., profession-based loans or credit offers) to match customer segments.
#
# **Negative**
#
# he slightly lower representation of certain professions like Managers or Accountants could indicate limited outreach or product mismatch in those segments.
# If ignored, Paisabazaar may miss potential high-value customers from these higher-income groups.
# To prevent negative growth, the company should increase marketing focus or introduce profession-specific financial schemes to attract these underrepresented occupations.

# %% [markdown]
# #### Chart - 3 Distribution of Credit Scores

# %%
# Chart - 3 visualization code
plt.figure(figsize=(6,5))
df['Credit_Score'].value_counts().plot(kind='bar')
plt.title('Distribution of Credit Scores')
plt.xlabel('Credit Score Category')
plt.ylabel('Number of Customers')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is ideal for visualizing categorical data like credit score categories.
# It clearly shows the proportion of customers in each credit category — Good, Standard, and Poor.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The majority of customers have a Standard credit score, followed by a significant number with Poor scores.
#
# * Only a small portion of customers fall in the Good credit score category.
#
# * This shows that most customers are moderate-risk borrowers, but a large share may still require credit improvement support.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive**
#
# Paisabazaar can use this insight to segment customers by risk — offering customized products:
#
# * Lower interest loans for customers with Good scores.
#
# * Credit repair or secured loan products for Poor score customers.
# This data-driven targeting can increase loan approval efficiency and reduce default risk.
#
# **Negative**
#
# The large proportion of customers with Poor and Standard scores suggests higher credit risk within the customer base.
# This could lead to increased loan defaults or losses if not managed properly.
# To prevent negative growth, Paisabazaar should focus on credit awareness programs and promote responsible borrowing behavior among these groups.

# %% [markdown]
# #### Chart - 4 Distribution of Number of Loans

# %%
# Chart - 4 visualization code
plt.figure(figsize=(8,5))
plt.hist(df['Num_of_Loan'], bins=10, color='orange', edgecolor='black')
plt.title('Distribution of Number of Loans')
plt.xlabel('Number of Loans')
plt.ylabel('Number of Customers')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is ideal for analyzing the distribution of numerical data.
# Here, it helps visualize how many loans each customer typically holds, which is important for assessing overall credit exposure.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Most customers have between 2 to 4 loans, showing that multi-loan holding is common.
#
# * Very few customers have more than 6 loans, suggesting limited over-leveraging.
#
# * The distribution gradually declines after 4 loans, indicating a stable and moderate borrowing pattern among most customers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive**
#
# This insight helps Paisabazaar identify loan-holding behavior across its customer base.
# Customers with 1–4 loans represent a balanced credit portfolio and may be suitable for cross-selling new financial products, such as top-up or home renovation loans.
# This allows better risk segmentation and targeted loan marketing.
#
# **Negative**
#
# Customers with 6 or more loans might indicate high financial burden and potential repayment risk.
# If not monitored, these customers could default on payments, leading to higher non-performing assets (NPAs).
# Paisabazaar should monitor these high-loan customers closely and consider credit limit adjustments or loan restructuring options.

# %% [markdown]
# #### Chart - 5 Age vs Credit Score

# %%
# Chart - 5 visualization code
plt.figure(figsize=(8,5))
sns.boxplot(data = df, x= 'Credit_Score', y = 'Age')
plt.title('Age vs Credit Score')
plt.xlabel("Credit Score Category")
plt.ylabel('Age')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A boxplot is ideal for comparing the distribution of a numerical variable (Age) across different categorical groups (Credit_Score).
# It helps visualize how customer age varies with credit score categories, showing both the spread and median trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Customers with Good credit scores tend to fall in the 30–45 age range, showing stable financial behavior.
#
# * Younger customers (under 25) are more likely to have Poor or Standard scores — possibly due to limited credit history or lack of repayment experience.
#
# * Older customers (above 50) also show a wider range of scores, which could be influenced by accumulated loans or varying repayment habits.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive**
#
# This insight helps Paisabazaar understand how creditworthiness changes with age.
# The company can:
#
# Target younger customers with starter credit cards or small personal loans to help build credit history.
#
# Offer custom financial plans to middle-aged customers who show responsible credit behavior.
#
# Provide debt restructuring or advisory services for older customers with multiple loans.
#
# **Negative**
#
# If the younger age group continues to display poor credit behavior, it could increase future default rates as this segment grows.
# Paisabazaar should invest in credit education programs and monitor early repayment patterns to reduce long-term credit risk.

# %% [markdown]
# #### Chart - 6 Annual Income vs Credit Score

# %%
# Chart - 6 visualization code
plt.figure(figsize = (8,5))
sns.boxplot(data = df, x = 'Credit_Score', y= 'Annual_Income')
plt.title("Annual Income vs Credit Score")
plt.xlabel('Credit Score')
plt.ylabel('Annual Income')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A boxplot is best suited to compare the distribution of a numerical variable (Annual Income) across categorical groups (Credit Score).
# It helps to visualize how income levels vary among customers with different credit ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Customers with Good credit scores tend to have higher annual incomes, with most earning between ₹40,000 and ₹100,000.
#
# * Standard score customers earn moderately less, while those with Poor scores mostly fall in the lower-income range (below ₹40,000).
#
# * The median income clearly increases with higher credit score categories, showing a positive correlation between income and credit quality.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive**
#
# * This insight helps Paisabazaar understand how income levels differ across customers with different credit scores.
#
# * The company can target high-income customers with good credit scores for premium credit cards, higher loan limits, and investment products.
#
# * Customers with standard credit scores and mid-range income can be offered moderate and risk-controlled loan plans.
#
# * Customers with poor credit scores and lower income can be placed under stricter credit checks to reduce default risk.
#
# **Negative**
#
# * The presence of high-income outliers in the Standard and Poor credit score groups indicates income–credit mismatch, which may mislead credit decisions.
#
# * Income ranges overlap across credit score categories, meaning income alone cannot reliably predict repayment behavior.
#
# Paisabazaar should avoid relying only on income and must combine it with repayment history, loan behavior, and utilization patterns to prevent future defaults.

# %% [markdown]
# #### Chart - 7 Occupation vs Credit Score

# %%
# Chart - 7 visualization code
plt.figure(figsize = (8,5))
sns.countplot(x = 'Occupation', hue = 'Credit_Score', data = df)
plt.title("Occupation vs Credit Score")
plt.xlabel('Occupation')
plt.ylabel('Number of Customers')
plt.xticks(rotation = 55, ha = 'right', fontsize = 10)
plt.legend(bbox_to_anchor=(1.05,1), loc = 'upper left')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A countplot is ideal for comparing how many customers belong to each occupation based on their Credit Score category.
#
# * It visually shows the frequency distribution of credit scores across different occupations.
#
# * This chart makes it simple to see which job groups have more good, standard, or poor credit customers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Standard credit score dominates across all occupations.
#
# * Occupations like Engineer, Developer, Lawyer, Architect have more customers with good credit scores.
#
# * Occupations such as Teacher, Journalist, Mechanic, Musician show relatively higher counts of poor credit scores.
#
# * The chart reveals how customer credit behavior differs by profession.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive**
#
# * Helps Paisabazaar identify occupations with strong credit profiles and target them with premium financial products.
#
# * Occupations with balanced or improving credit scores can be offered moderate-risk loans.
#
# * Supports better segmentation, improving loan approval accuracy and reducing credit risk.
#
# **Negative**
#
# * Some occupations showing more poor-score customers may pose higher default risk.
#
# * Depending only on occupation for decision-making can lead to inaccurate credit judgments.
#
# * Must be combined with income, repayment behavior, credit utilization, and loan history to avoid bad lending decisions.

# %% [markdown]
# #### Chart - 8 Credit Utilization Ratio vs Credit Score

# %%
# Chart - 8 visualization code
plt.figure(figsize=(8,5))
sns.boxplot(data = df, x = 'Credit_Score', y = 'Credit_Utilization_Ratio')
plt.title('Credit Utilization Ratio vs Credit Score')
plt.xlabel('Credit Score')
plt.ylabel('Credit Utilization Ratio')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A boxplot is ideal for comparing the distribution of a numerical variable (Credit Utilization Ratio) across categorical groups (Credit Score).
#
# * It shows medians, spread, and potential outliers clearly.
#
# * This chart helps identify whether customers with poor credit scores use more of their available credit.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * All three groups (Good, Standard, Poor) have similar median credit utilization around 30–35%.
#
# * The Poor credit score group shows slightly higher upper values, indicating heavier credit usage among some customers.
#
# * The Standard group has more visible outliers, suggesting inconsistent utilization behavior.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive**
#
# * Helps Paisabazaar identify customers who manage their credit well (lower utilization).
#
# * Customers with stable utilization ratios can be targeted for pre-approved loans and credit limit increases.
#
# * Supports better segmentation for risk assessment.
#
# **Negative**
#
# * Higher utilization levels among some Poor credit score customers indicate increased chances of missed or delayed payments.
#
# * Relying only on utilization may be misleading—customers with good income may still have higher usage but lower risk.
#
# * Paisabazaar must combine utilization insights with income, debt, and repayment history to avoid risky approvals.

# %% [markdown]
# #### Chart - 9 Payment Behaviour vs Credit Score

# %%
# Chart - 9 visualization code
plt.figure(figsize= (8,5))
sns.countplot(data = df, x = 'Payment_Behaviour', hue = 'Credit_Score')
plt.title('Payment Behaviour vs Credit Score')
plt.xlabel('\nPayment Behaviour\n')
plt.ylabel('Number of Customers')
plt.xticks(rotation = 35, ha = 'right', fontsize = 8)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A countplot is ideal for comparing how many customers fall into each Payment Behaviour category across different Credit Score groups.
#
# It clearly shows which payment patterns are more common among good, standard, and poor credit customers.
#
# The chart helps identify which spending behaviors indicate higher or lower credit risk.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Standard credit score group dominates across all payment behavior categories.
#
# * Customers with Good credit scores are more concentrated in
#
#     * High_spent_Medium_value_payments
#
#     * High_spent_Large_value_payments
#
# * Customers with Poor credit scores show higher counts in
#
#     * Low_spent_Small_value_payments
#
#     * Low_spent_Medium_value_payments
#
# * Heavy spenders with medium/large payments tend to have better credit scores, while inconsistent low-value spending patterns appear more in poor credit customers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive**
#
# * Helps Paisabazaar identify payment behavior patterns that are linked with good credit discipline.
#
# * Customers with consistent high/medium-value payments can be targeted for
#
#     * pre-approved loans
#
#     * credit limit upgrades
#
#     * premium financial products
#
# * Supports better segmentation and helps reduce credit risk through behavior-based profiling.
#
# **Negative**
#
# Customers with poor payment behavior (frequent small/low-value irregular payments) show weaker credit performance, indicating higher risk of delays or defaults.
#
# * Payment behavior alone cannot determine risk — it must be combined with income, outstanding debt, and utilization ratios.
#
# * Over-reliance on spending patterns may misclassify customers, especially those with fluctuating income.

# %% [markdown]
# #### Chart - 10 Occupation vs Payment Behaviour vs Avg Credit Score (Numeric)

# %%
# Chart - 10 visualization code

# Map Credit_Score to numerical values
credit_score_mapping = {'Good': 2, 'Standard': 1, 'Poor': 0}
df['Credit_Score_Numeric'] = df['Credit_Score'].map(credit_score_mapping)

grouped = df.groupby(['Occupation', 'Payment_Behaviour'])['Credit_Score_Numeric'].mean().unstack()

grouped.plot(kind='bar', figsize=(10,6))
plt.title("Occupation vs Payment Behaviour vs Avg Credit Score (Numeric)")
plt.xlabel("Occupation")
plt.ylabel("Average Credit Score (Numeric)")
plt.legend(title="Payment Behaviour")
plt.xticks(rotation = 45, ha = 'right')
plt.legend(bbox_to_anchor=(1.05,1), loc = 'upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart effectively visualizes three variables together:
# Occupation (Categorical) × Payment Behaviour (Categorical) × Average Credit Score (Numeric)
#
# It helps compare how different occupation groups behave financially when their payment behaviour patterns change.
#
# Useful for spotting which customer segments maintain good credit discipline and which segments display high-risk repayment patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Occupations such as Doctors, Lawyers, Managers, Engineers show consistently higher credit scores across all payment behaviour categories.
#
# For most occupations, customers showing High_spent_Large_value_payments or High_spent_Medium_value_payments tend to have better average credit scores.
#
# The Low_spent_Small_value_payments category shows the lowest credit scores across nearly all occupations, indicating a pattern of low repayment capacity or unstable cash flow.
#
# Occupations like Mechanic, Musician, Writer show slightly lower overall credit scores across behaviours, suggesting these groups might be more financially sensitive.
#
# 3️⃣ Will the insights help create a positive business impact? Are there negati

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive**
#
# Helps identify high-potential customer groups (Doctors, Engineers, Managers) for premium loan products with lower risk.
#
# Payment behaviour trends across occupations can guide risk-based pricing, improving loan profitability.
#
# Enables targeted interventions for customers who show risky payment behaviour, preventing defaults.
#
# Helps refine credit policies for specific occupations where repayment patterns are predictable.
#
# **Negative**
#
# Over-reliance on occupation-based segmentation may introduce bias or discrimination in lending decisions.
#
# Low-performing occupation groups may be unfairly categorized as risky without understanding underlying economic factors.
#
# If payment behaviour is affected by temporary events (job loss, medical emergency), the model may wrongly classify good customers as risky.
#
# Some categories may have fewer samples, leading to misleading averages.

# %% [markdown]
# #### Chart - 11 Stacked Bar Chart

# %%
# Chart - 11 visualization code

group = df.groupby('Credit_Mix')[['Num_of_Loan','Num_Credit_Inquiries']].mean()

group.plot(kind='bar', stacked=True, figsize=(10,6))
plt.title("Credit Mix vs Avg Loans + Credit Inquiries (Stacked)")
plt.xlabel("Credit Mix")
plt.ylabel("Average Count")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A stacked bar chart allows comparison of two numeric variables (Number of Loans + Number of Credit Inquiries) across one categorical variable (Credit Mix).
#
# It clearly shows the combined financial burden and credit activity level for each credit mix category (Good, Standard, Bad).
#
# Helpful for understanding how borrowing behaviour and inquiry frequency differ across credit profiles.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Bad Credit Mix group has the highest combined value of loans and credit inquiries, indicating:
#
#  * Multiple loans
#
# * Frequent credit inquiries
# These are strong indicators of financial distress or aggressive credit seeking.
#
# The Good Credit Mix group shows the lowest numbers, reflecting more stable borrowing behaviour and better financial discipline.
#
# The Standard Credit Mix sits in the middle, with moderate loan counts and moderate inquiry frequency.
#
# The clear gradient from Good → Standard → Bad highlights how credit usage patterns impact overall credit health.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive**
#
# Helps identify high-risk customer segments (Bad credit mix) who may need:
#
# * Stricter loan approval checks
#
# * Lower credit limits
#
# * More frequent monitoring
#
# Supports building risk-based pricing models, offering lower-interest loans to “Good” credit mix individuals.
#
# Helps in designing personalized credit improvement programs for customers with high inquiries and multiple loans.
#
# **Negative**
#
# Over-penalizing customers in the “Bad” category may lead to reduced loan approvals and loss of potential business.
#
# High inquiries may sometimes be due to comparison shopping, not necessarily financial stress—misinterpretation may lead to unfair scoring.
#
# Credit Mix categories may differ by demographic groups, creating the risk of unintentional bias.

# %% [markdown]
# #### Chart - 12 Age vs Credit Score vs Outstanding Debt

# %%
# Chart - 12 visualization code

age_group = df.groupby('Age').agg({
    'Credit_Score_Numeric': 'mean', # Use the numeric version of Credit_Score
    'Outstanding_Debt': 'mean'
}).reset_index() # Add reset_index() to make 'Age' a regular column for plotting

fig, ax1 = plt.subplots(figsize=(10,6))

ax1.plot(age_group['Age'], age_group['Credit_Score_Numeric'], label='Average Credit Score (Numeric)')
ax1.set_xlabel("Age")
ax1.set_ylabel("Average Credit Score (Numeric)")

ax2 = ax1.twinx()
ax2.plot(age_group['Age'], age_group['Outstanding_Debt'], color='red', label='Average Outstanding Debt')
ax2.set_ylabel("Average Outstanding Debt")

plt.title("Age vs Average Credit Score (Numeric) vs Average Outstanding Debt")
fig.legend(loc='upper right', bbox_to_anchor=(1.2,1.2), bbox_transform=ax1.transAxes)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A dual-axis line chart allows you to visualize two numeric variables (Credit Score & Outstanding Debt) simultaneously across one continuous variable (Age).
#
# It helps compare how credit health and debt levels change as people age.
#
# This chart is simple, clear, and effectively shows multi-variable financial behavior patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Younger customers (age 18–25) tend to show lower credit scores and higher outstanding debt, indicating early-stage financial instability or over-borrowing.
#
# From age 25–40, credit scores stabilize while outstanding debt becomes moderate, suggesting better financial maturity.
#
# Customers above 45 show significantly higher credit scores and much lower outstanding debt, reflecting good repayment habits and financial stability.
#
# The inverse trend between the two lines (as age increases, debt decreases and credit score increases) suggests strong relationship between experience and credit discipline.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive**
#
# Helps lenders tailor loan products by age group (e.g., lower limit for 18–25, premium offers for 45+).
#
# Identifies age segments that are more financially stable and lower risk.
#
# Supports age-based risk scoring to reduce default probability.
#
# Can guide targeted financial education for younger customers to avoid early debt traps.
#
# **Negative**
#
# Over-reliance on age can lead to age-based discrimination, affecting fairness.
#
# Younger adults may be unfairly penalized if their temporary high debt is misinterpreted.
#
# Economic conditions differ by generation; older customers may appear safer just due to accumulated savings, not better behaviour.
#
# If dataset has fewer elderly customers, the trend may be biased.

# %% [markdown]
# #### Chart - 13 Payment Behaviour vs Credit Score across Credit Mix

# %%
# Chart - 13 visualization code

plt.figure(figsize=(8,6))
sns.boxplot(
    x='Payment_Behaviour',
    y='Credit_Score',
    hue='Credit_Mix',
    data=df
)
plt.title("Payment Behaviour vs Credit Score across Credit Mix")
plt.xticks(rotation = 45, ha = 'right')
plt.legend(loc='upper right', bbox_to_anchor=(1.2,1))
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart allows comparison of three variables at once:
#
# * Payment Behaviour (categorical)
#
# * Credit Mix (categorical, used as hue)
#
# * Credit Score (numeric)
#
# A boxplot is ideal for showing the distribution, spread, and variability of credit scores for different behavioural groups.
#
# It helps understand how payment habits + mix of credit jointly influence a person’s credit score.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Good Credit Mix consistently aligns with higher credit score ranges across almost all payment behaviours.
#
# Bad Credit Mix categories show lower credit score distributions, regardless of payment behaviour — meaning poor credit diversity heavily affects scoring.
#
# Customers with High_spent_Large_value_payments and High_spent_Medium_value_payments tend to fall in better credit score ranges compared to “Low_spent” categories.
#
# “Low_spent_Small_value_payments” shows more widespread and lower credit score distribution — a possible sign of cash-flow issues.
#
# Even within the same payment behaviour, the Credit Mix type creates clear differences in scoring.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive**
#
# Provides deeper behavioural segmentation for risk profiling.
#
# Helps identify customers with high spending but consistent payments as strong credit candidates.
#
# Can be used to design behaviour-linked credit score improvement programs, targeting customers in low-scoring buckets.
#
# Helps in understanding how credit diversification (mix) contributes to better creditworthiness.
#
# **Negative**
#
# Payment behaviour labels may be influenced by short-term spending patterns, not long-term habits — risk of misclassification.
#
# Differences between credit mix groups may create bias toward customers who naturally have access to diverse credit products.
#
# Some categories may have fewer samples, causing misleading box distributions.
#
# Overuse in lending decisions may penalize customers who spend less but are financially conservative (low-spent customers are not necessarily risky).

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
num_cols = df.select_dtypes(include = ['int64', 'float64']).columns
corr = df[num_cols].corr()

plt.figure(figsize = (12,8))
plt.imshow(corr, cmap = 'viridis')
plt.colorbar()
plt.xticks(range(len(num_cols)), num_cols, rotation = 90)
plt.yticks(range(len(num_cols)), num_cols)
plt.title("Correlation Heatmap")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap helps visualize relationships between multiple numerical variables at the same time.
#
# It highlights strong positive or negative correlations, helping identify which features move together and which work against each other.
#
# Useful for detecting variables that may heavily influence credit score, credit risk, and customer financial behaviour.
#
# It provides a clear overview and helps eliminate redundant or highly correlated features before modeling.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Credit Utilization Ratio shows a strong negative correlation with Credit Score, meaning customers who use more of their credit limit tend to have lower credit scores.
#
# Outstanding Debt is positively correlated with EMI per month, as expected — higher debt generally leads to higher EMIs.
#
# Monthly Balance shows a positive correlation with Annual Income and Monthly Inhand Salary, indicating higher-income customers maintain more savings.
#
# Num_of_Loan and Num_Credit_Inquiries show a moderate correlation, suggesting customers with more loans tend to make more inquiries.
#
# Variables like Changed Credit Limit, Month, and Customer_ID show almost no correlation with others, meaning they may not add predictive value.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(df[['Annual_Income', 'Outstanding_Debt', 'Credit_Utilization_Ratio', 'Credit_Score']], diag_kind = 'kde')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot allows visualization of multiple variables simultaneously, showing:
#
# Individual feature distributions (diagonal)
#
# Relationships between every pair of features (scatter plots)
#
# It is one of the most effective multivariate tools to quickly spot patterns, trends, correlations, and outliers.
#
# Helps understand how income, debt, and credit utilization behave jointly — essential for credit risk analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Annual Income Distribution: Right-skewed — more customers fall into mid-to-low income brackets with few very high-income customers.
#
# Outstanding Debt vs Annual Income: No strong linear correlation; even high-income customers may have high or low outstanding debt, suggesting mixed borrowing behaviour.
#
# Credit Utilization vs Outstanding Debt: Slight upward trend — as debt increases, utilization tends to rise, indicating greater credit consumption.
#
# Credit Utilization Distribution: Mostly concentrated around the middle ranges (25–45%), indicating moderate usage by most customers.
#
# Several scatter plots show clusters indicating distinct behavioural segments (e.g., low debt + low utilization, high debt + high utilization).

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# The analysis shows that customer financial behaviour is strongly influenced by factors like credit utilization, outstanding debt, payment habits, age, and credit mix. Customers with high credit utilization, frequent delayed payments, and multiple credit inquiries tend to have lower credit scores and higher financial risk. Younger customers also show higher outstanding debt and lower scores, while older individuals generally maintain better credit health. Occupations such as Doctor, Engineer, and Manager display stronger repayment discipline, whereas groups like Mechanics, Writers, and Musicians show comparatively weaker credit patterns. These findings suggest that Paisabazaar should build a structured risk assessment system that focuses on these high-impact indicators. Customers with consistent payment behaviour, diversified credit mix, and controlled debt can be targeted with pre-approved loans, premium credit cards, or higher credit limits. Those showing warning signs—high inquiries, rising debt, low-value irregular spending—should receive closer monitoring, reminders, and tailored guidance to avoid defaults. By segmenting customers based on income stability, age, credit behaviour, and loan patterns, Paisabazaar can improve decision-making, reduce risky approvals, and design personalized financial products. This approach helps increase profitability, lower default rates, and offer fair, responsible lending that supports long-term customer relationships.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# * Key finding: High credit utilization, large outstanding debt, frequent inquiries, and poor payment behaviour are the strongest signals of low creditworthiness.
#
# * Business impact: Start with rule-based flags and a dashboard to reduce immediate risk, then move to a validated ML score to improve approvals and detect fraud at scale.
#
# * Goal: Improve approval quality (fewer bad loans) while keeping good-customer conversions high.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
